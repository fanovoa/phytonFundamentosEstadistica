# %%
# importando las librerías requeridas
import pandas as pd

# %% [markdown]
# # Unidad 1: Actividad Individual
# Con el desarrollo de esta actividad podrás medir el nivel de apropiación de los temas de la Unidad 1. Es muy importante que sigas las instrucciones dadas en cada uno de los ejercicios. En particular, debes eliminar las partes del código que contienen la siguiente frase una vez hayas implementado tu solución:
#
# `raise NotImplementedError() # Remueve esta línea cuando implementes tu solución.`
#
# Una vez hayas implementado y probado todas las soluciones, debes subir este notebook a la actividad correspondiente en nuestra Aula Virtual.

# %% [markdown]
# ## Caso 0

# %% [markdown]
# ### Ejercicio 0.1:
# Define una variable con tu nombre completo, la variable se debe llamar `ex_1_result`:

# %%
# Llama a la variable con tu nombre ex_1_result
# INGRESA TU CÓDIGO AQUÍ 
ex_1_result = "Victor Fabian Novoa Rojas"
print(ex_1_result)
# Out:
# Victor Fabian Novoa Rojas

# %% [markdown]
# ### Ejercicio 0.2:
# Escribe un código que encuentre el valor del producto de las siguientes variables (¡no las modifiques!). Asigna el resultado del producto a una variable denominada `ex_2_result`.

# %%
a = 5
b = 3
c = -1
d = 4.6
# Llama a la variable con tu nombre ex_2_result
# INGRESA TU CÓDIGO AQUÍ
ex_2_result = a*b*c*d
print(ex_2_result)
# Out:
# -69.0

# %% [markdown]
# ### Ejercicio 0.3:
# Escribe una función que tome como entrada una string de contenido numérico; es decir, strings del tipo `"2"`, `"3.15"`, `"-4.52"`; convierta el valor de la string a formato numérico y posteriormente divida este valor por la longitud total de la string. El nombre de esta función debe ser `ex_3_function`
#
# **Ayuda:** Para obtener la longitud de una string podemos usar la función `len()`.

# %%
# recuerda llamar la función como ex_3_function
# INGRESA TU CÓDIGO AQUÍ 
def ex_3_function(x):
    return (float(x)*1)/len(x)

print(ex_3_function("2"))
print(ex_3_function("3.15"))
print(ex_3_function("-4.52"))
# Out:
# 2.0
# 0.7875
# -0.9039999999999999

# %% [markdown]
# ### Ejercicio 0.4:
# Escribe una función que acepte como entrada un número y una string cualquiera. La función debe hacer la suma del número y la longitud de la string. Recuerda que para obtener la longitud de la string debes usar la funcion `len()`. El nombre de esta función debe ser `ex_4_function`

# %%
# recuerda llamar la función como ex_4_function
# INGRESA TU CÓDIGO AQUÍ 
def ex_4_function(numero, palabra):
    return numero + (len(palabra))

print(ex_4_function(5, "Hola"))
# Out:
# 9

# %% [markdown]
# ## Caso 1

# %% [markdown]
# ### Ejercicio 1.1
# La imagen siguiente tiene un listado de las tasas de interés para crédito hipotecario proporcionadas por diferentes bancos. Crea un diccionario llamado `tasas` en el que cada llave sea el nombre del banco, y el item correspondiente sea la tasa de interés en formato numérico.
#
# **OJO** Para el nombre del banco usa solo minúsculas y omite los acentos.
# Ejemplos:
# - Banco Popular -> `banco popular`
# - AV Villas -> `av villas`
# - Bancoomeva -> `bancoomeva`
# - Banco de Bogotá -> `banco de bogota`
#
#  ![Picture title](fig/image-20211025-194355.png)
#
#  Obtenido de https://forbes.co/2021/01/22/economia-y-finanzas/estos-son-los-bancos-que-ofrecen-las-mejores-tasas-para-compra-de-vivienda/ el 26 Octubre de 2021

# %%
# Recuerda que el diccionario se debe llamar tasas
# INGRESA TU CÓDIGO AQUÍ 
tasas = {
    'bancoomeva': 8.99,
    'banco popular': 9.28,
    'av villas': 9.97,
    'scotiabank colpatria': 10.21,
    'bbva colombia': 10.24,
    'bancolombia': 10.65,
    'banco caja social': 11.17,
    'banco de bogota': 11.75,
    'davivienda': 11.77,
    'bancompartir': 12.22,
}

print(tasas)
# Out:
# {'bancoomeva': 8.99, 'banco popular': 9.28, 'av villas': 9.97, 'scotiabank colpatria': 10.21, 'bbva colombia': 10.24, 'bancolombia': 10.65, 'banco caja social': 11.17, 'banco de bogota': 11.75, 'davivienda': 11.77, 'bancompartir': 12.22}

# %% [markdown]
# ### Ejercicio 1.2:
# Escribe un código que encuentre el valor promedio de la tasa de interés entre los bancos listados en `tasas`, dale a este valor el nombre de `tasa_promedio`.
#
# **Pista:** Recuerda que para acceder a la lista de valores de un diccionario puedes usar la función `dicc.values()`, para sumar los valores de una lista puedes usar `sum(lista)` y para obtener el número de elementos en una lista puedes usar `len()`.

# %%
# Recuerda llamar al promedio tasa_promedio
# INGRESA TU CÓDIGO AQUÍ
tasa_promedio = sum(tasas.values()) / len(tasas)
print(tasa_promedio)
# Out:
# 10.625

# %% [markdown]
# ### Ejercicio 1.3:
# La siguiente lista, `lista_dup`, contiene una serie de strings. Escriba código para realizar las siguientes tareas:
#
# - Eliminar los valores duplicados
# - Ordenar los elementos de la lista por orden alfabético.
#
# La lista sin duplicados y con los elementos ordenados se debe llamar `list_ord`.
#
# **Pista:** Recuerda que al convertir una lista en un conjunto se eliminan los elementos duplicados y que existe una función que permite ordenar los elementos de una lista.

# %%
lista_dup = ['manzana', 'pera', 'manzana', 'fresa', 'piña', 'coco', 'fresa', 'guayaba', 'piña',
            'coco', 'manzana', 'piña', 'papaya', 'manzana', 'mandarina', 'pera', 'guayaba', 
            'melón', 'granadilla', 'coco', 'papaya', 'melón']
# Recuerda que la lista ordenada y sin duplicados se debe llamar list_ord
# INGRESA TU CÓDIGO AQUÍ 
list_ord = sorted(set(lista_dup))
print(list_ord)
# Out:
# ['coco', 'fresa', 'granadilla', 'guayaba', 'mandarina', 'manzana', 'melón', 'papaya', 'pera', 'piña']

# %% [markdown]
# ### Ejercicio 1.4:
# La figura muestra dos conjuntos de letras A y B:
# ![Picture title](fig/C1_1.png)
#
# Escribe código en Python que realice las siguientes actividades:
#
# - Crear los conjuntos A y B y les asigne las letras correspondientes.
# - Calcular la intersección entre los dos conjuntos y la almacene en un conjunto llamada `intersect`.
# - Calcular cuántas letras diferentes hay al juntar los dos conjuntos y almacene este número como `n_letras`.
# - Calcular qué letras de B no están en A y almacene este conjunto de letras como `diff`.

# %%
# INGRESA TU CÓDIGO AQUÍ 
A= {'e','h','n','o','t','y','z','m','b','c','a','q','r','l'}
B= {'d','c','i','h','j','w','z','r','m','a','u','b','p'}

intersect = A & B
n_letras = len(A|B)
diff = B -A

print(intersect)
print(n_letras)
print(diff)
# Out:
# {'z', 'h', 'r', 'a', 'b', 'c', 'm'}
# 20
# {'w', 'j', 'd', 'u', 'i', 'p'}

# %% [markdown]
# # Caso 2

# %% [markdown]
# ### Ejercicio 2.1
# Continuemos con nuestro análisis de estaciones de servicio, pero esta vez enfoquémonos sólo en la gasolina. Supongamos que la información de cada estación de servicio es entregada como una lista en el que el primer elemento es el nombre de la estación, el segundo elemento es el nombre del departamento, y el tercer elemento es el precio de la gasolina. A continuación se muestran dos ejemplos:

# %%
# Ejemplo 1 de estación de servicio
EDS1 = [
    'BOMBA UNICA LA PISTA',  # nombre estación
    'AMAZONAS',              # departamento
    14000                    # precio gasolina
]

# ejemplo 2 de estación de servicio
EDS2 = [
    'CENTRO DE SERVICIOS SAN FRANCISCO	',  # nombre estación
    'MAGDALENA',                            # departamento
    8322                                    # precio gasolina
]

# %% [markdown]
# Al igual que en el caso, la información de los valores promedio de la gasolina y su desviación estandar en 10 departamentos se entrega en forma de los siguientes diccionarios:

# %%
gasolina_prom = {
    'ANTIOQUIA': 8246,
    'ATLANTICO': 8252,
    'BOGOTA D.C.': 8418,
    'CAQUETA': 7283,
    'CESAR': 8313,
    'CHOCO': 7196,
    'CUNDINAMARCA': 8543,
    'MAGDALENA': 7626,
    'QUINDIO': 8079,
    'SUCRE': 8258
    }

gasolina_desv = {
    'ANTIOQUIA': 495,
    'ATLANTICO': 421,
    'BOGOTA D.C.': 304,
    'CAQUETA': 465,
    'CESAR': 371,
    'CHOCO': 682,
    'CUNDINAMARCA': 419,
    'MAGDALENA': 679,
    'QUINDIO': 362,
    'SUCRE': 269
}

# %% [markdown]
# Sin embargo, a diferencia del caso, queremos hacer un análisis un poco más específico en el que, dependiendo de la diferencia del precio de la gasolina en la estación con el promedio del Departamento, a cada estación se le agrege uno de los siguientes códigos:
#
# ![Picture title](fig/C2_2.png)
#
# En la figura $\bar{p}$ representa el valor promedio en el departamento, y $\sigma$ representa la desviación estandar del precio de la gasolina en el departamento. Por ejemplo, la clasificación `'---'` se asigna a estaciones de gasolina cuyo precio esté entre $\bar{p} - 2\sigma$ y $\bar{p} - \frac{3\sigma}{2}$.

# %% [markdown]
# Modifica la función siguiente de manera que dada una estación de servicio (en el formato de lista mostrado arriba), y los valores promedios y de desviación estándar (en el formato de diccionario mostrado arriba), retorne un string con la clasificación que se acaba de definir en caso de que la estación esté en uno de los Departamentos de los que poseemos información, o retorne el string `'NoData'` en caso contrario.
#
# No modifiques el nombre de la función.

# %%
# No modifiques el nombre de la función
def clasificar_EDS ( edslist, promdict, desvdict):
    # edsdict es la lista con la información de la estación de servicio
    # promdict es el diccionario con los precios promedio de la gasolina
    # desvdict es el diccionario con la desviación estándar del precio de la gasolina

    # INGRESA TU CÓDIGO AQUÍ
    depto = edslist[1]
    if depto not in  promdict.keys():
        return "NoData"

    valor = edslist[2]
    promedio = promdict[depto]
    desviacion = desvdict[depto]
    formula = [ desviacion/2 , desviacion, (3*desviacion)/2 , 2*desviacion ]

    
    if valor < promedio - formula[3]:
        return "----"
    elif valor < promedio - formula[2]:
        return "---"
    elif valor < promedio - formula[1]:
        return "--"
    elif valor < promedio - formula[0]:
        return "-"
    elif valor < promedio + formula[0]:
        return "o"
    elif valor < promedio + formula[1]:
        return "+"
    elif valor < promedio + formula[2]:
        return "++"
    elif valor < promedio + formula[3]:
        return "+++"
    else:
        return "++++"

clasificar_EDS


#print(clasificar_EDS(EDS1, gasolina_prom, gasolina_desv))
#print(clasificar_EDS(EDS2, gasolina_prom, gasolina_desv))
# Out:
# NoData
# ++

# %% [markdown]
# ### Ejercicio 2.2
#
# A continuación cargaremos de nuevo la base de datos de estaciones de servicio del país y sus precios de gasolina y diesel:

# %%
EDS_df = pd.read_excel('data/precios_combustible_dic_2020.xlsx')

# %% [markdown]
# Escribe un código que escanee las filas del DataFrame EDF_df, para cada fila el código debe generar una lista con el formato [*nombre_eds*, *departamento*, *precio_gasolina*] y aplicar la función `clasificar_EDS` para obtener la clasificación. El resultado del código debe ser una lista llamada `clasificaciones` que contiene las salidas de aplicar la función de clasificación para todas las EDS de la base de datos.

# %%
# Primero definimos la lista de clasificaciones
clasificaciones = []

# INGRESA TU CÓDIGO AQUÍ
# EDS_df
for index in EDS_df.index:
    eds = [EDS_df.loc[index,'nombrecomercial'], EDS_df.loc[index,'NombreDepartamento'], EDS_df.loc[index,'gasolina_corriente']]
    clasificaciones.append(clasificar_EDS(eds, gasolina_prom, gasolina_desv))

#print(len(clasificaciones))
#print(clasificaciones[:30])
#print(clasificaciones[0])
#print(clasificaciones[4000])

# %% [markdown]
# ### Ejercicio 2.3
# Escribe un código para determinar el porcentaje de estaciones de servicio extremadamente caras, es decir, el porcentaje de estaciones de servicio con clasificación `'+++'` o `'++++'`. El valor del porcentaje debe ser asignado a la variable `porc_caras` y debe estar en el rango entre 0 y 100.

# %%
# Recuerda asignar el porcentaje a la variable porc_caras
# INGRESA TU CÓDIGO AQUÍ
eds_caras = []
for caras in clasificaciones:
    if caras in ["+++", "++++"]:
        eds_caras.append(caras)

porc_caras = (len(eds_caras) / len(clasificaciones)) * 100

# print(porc_caras)

# %% [markdown]
# ### Ejercicio 2.4
# Escribe ahora un código para determinar el porcentaje de estaciones de servicio extremadamente baratas, es decir, el porcentaje de estaciones de servicio con clasificación `'---'` o `'----'`. El valor del porcentaje debe ser asignado a la variable `porc_baratas` y debe estar en el rango entre 0 y 100.

# %%
# Recuerda asignar el porcentaje a la variable porc_baratas
# INGRESA TU CÓDIGO AQUÍ
eds_baratas = []
for baratas in clasificaciones:
    if baratas in ["---", "----"]:
        eds_baratas.append(baratas)

porc_baratas = (len(eds_baratas) / len(clasificaciones)) * 100

# print(porc_baratas)

# %% [markdown]
# ### Verificando las respuestas
# No modifiques las celdas siguientes, sólo ejecútalas para conocer si las soluciones propuestas cumplen con los estándares requeridos. Asegúrate de haber corrido todo el notebook antes de correr las celdas de verificación.
#
# Esta es sólo una validación preliminar, todas tus soluciones serán sometidas a pruebas adicionales para dar una puntuación.

# %%
# Ejercicio 0.1
assert "ex_1_result" in globals(), "Ej. 0.1 - No definiste una variable llamada ex_1_result"
assert type(ex_1_result) == type("test"), "Ej. 0.1 - La variable ex_1_result no es del tipo string"
assert len(ex_1_result.split()) > 1, "Ej. 0.1 - La variable ex_1_result contiene sólo una palabra, debe corresponder a tu nombre completo"
print("¡El Ejercicio 0.1 luce bien!")
# Out:
# ¡El Ejercicio 0.1 luce bien!

# %%
# Ejercicio 0.2
assert "ex_2_result" in globals(), "Ej. 0.2 - No definiste una variable llamada ex_2_result"
assert type(ex_2_result) == type(0.1), "Ej. 0.2 - La variable ex_2_result no es del tipo flotante (float)"
assert ex_2_result == -69, "Ej. 0.2 - El resultado es incorrecto. Deberías haber obtenido -69 pero la respuesta es "+ ex_2_result
print("¡El Ejercicio 0.2 luce bien!")
# Out:
# ¡El Ejercicio 0.2 luce bien!

# %%
# Ejercicio 0.3
assert "ex_3_function" in globals(), "Ej. 0.3 - No definiste una función llamada ex_3_function"
assert type(ex_3_function)==type(lambda x: x), "Ej. 0.3 - La variable ex_3_function no está definida como una función"
assert ex_3_function("0.1")== 0.1/3, "Ej. 0.3 - La función arroja valores incorrectos, debes revisar su definición"
assert ex_3_function("-3.1415")== -3.1415/7, "Ej. 0.3 - La función arroja valores incorrectos, debes revisar su definición"
print("¡El Ejercicio 0.3 luce bien!")
# Out:
# ¡El Ejercicio 0.3 luce bien!

# %%
# Ejercicio 0.4
assert "ex_4_function" in globals(), "Ej. 0.4 - No definiste una función llamada ex_4_function"
assert type(ex_4_function)==type(lambda x: x), "Ej. 0.4 - La variable ex_4_function no está definida como una función"
assert ex_4_function(0.1,'hola')== 4.1, "Ej. 0.4 - La función arroja valores incorrectos, debes revisar su definición"
assert ex_4_function(-3.5,"house")== 1.5, "Ej. 0.4 - La función arroja valores incorrectos, debes revisar su definición"
print("¡El Ejercicio 0.4 luce bien!")
# Out:
# ¡El Ejercicio 0.4 luce bien!

# %%
# Ejercicio 1.1
assert "tasas" in globals(), "Ej. 1.1 - No definiste una variable llamada tasas"
assert type(tasas) == type({}), "Ej. 1.1 - La variables tasas no es del tipo diccionario"
assert len(tasas) == 10, "Ej. 1.1 - La variable tasas no contiene exactamento 10 elementos"
assert sum(tasas.values()) == 106.25, "Ej. 1.1 - Hay un problema con los valores del diccionario"
assert max(tasas.values()) == 12.22, "Ej. 1.1 - Hay un problema con los valores del diccionario"
assert 'banco de bogota' in tasas.keys(), "Ej. 1.1 - Verifica la definición de las llaves en el diccionario"
assert 'av villas' in tasas.keys(), "Ej. 1.1 - Verifica la definición de las llaves en el diccionario"
print("¡El Ejercicio 1.1 luce bien!")
# Out:
# ¡El Ejercicio 1.1 luce bien!

# %%
# Ejercicio 1.2
assert "tasa_promedio" in globals(), "Ej. 1.2 - No definiste una variable llamada tasa_promedio"
assert type(tasa_promedio) == type(0.1), "Ej. 1.2 - La variable tasa_promedio no es del tipo flotante (float)"
assert tasa_promedio == 10.625, "Ej. 1.2 - El resultado es incorrecto. Deberías haber obtenido 10.625 pero la respuesta es " + tasa_promedio
print("¡El Ejercicio 1.2 luce bien!")
# Out:
# ¡El Ejercicio 1.2 luce bien!

# %%
# Ejercicio 1.3
assert "list_ord" in globals(), "Ej. 1.3 - No definiste una función llamada list_ord"
assert type(list_ord)==type([]), "Ej. 1.3 - La variable list_ord no está definida como una lista"
assert len(list_ord)<=10, "Ej. 1.3 - La lista list_ord aún contiene elementos repetidos"
assert len(list_ord)>=10, "Ej. 1.3 - La lista list_ord tiene menos elementos de los que debería tener"
assert list_ord[0] == 'coco', "Ej. 1.3 - La lista list_ord no está ordenada alfabéticamente"
assert list_ord[-1] == 'piña', "Ej. 1.3 - La lista list_ord no está ordenada alfabéticamente"
print("¡El Ejercicio 1.3 luce bien!")
# Out:
# ¡El Ejercicio 1.3 luce bien!

# %%
# Ejercicio 1.4
assert "intersect" in globals(), "Ej. 1.4 - No definiste una variable llamada intersect"
assert len(intersect) == 7, "Ej. 1.4 - hay un problema con el cálculo de la variable intersect, no tiene el número de elementos que debería"
assert type(intersect)==type({1}), "Ej. 1.4 - La variable intersect no está definida como un conjunto"
assert "n_letras" in globals(), "Ej. 1.4 - No definiste una variable llamada n_letras"
assert n_letras == 20, "Ej. 1.4 - El cálculo del total de letras diferentes en los dos conjuntos está errado"
assert "diff" in globals(), "Ej. 1.4 - No definiste una variable llamada diff"
assert len(diff) == 6, "Ej. 1.4 - Hay un problema con el cálculo de la variable diff, no tiene el número de elementos que debería"
assert type(diff)==type({1}), "Ej. 1.4 - La variable diff no está definida como un conjunto"
print("¡El Ejercicio 1.4 luce bien!")
# Out:
# ¡El Ejercicio 1.4 luce bien!

# %%
# Ejercicio 2.1
assert clasificar_EDS(EDS1, gasolina_desv, gasolina_prom) == 'NoData', "Ej. 2.1 - La salida de la función clasificar_EDS no está bien definida para el caso en el que el Departamento no está entre los datos."
assert clasificar_EDS(EDS2, gasolina_desv, gasolina_prom) == '++', "Ej. 2.1 - La salida de la función clasificar_EDS no está bien definido."
assert clasificar_EDS(['EDS1', 'MAGDALENA', 7600], gasolina_desv, gasolina_prom) == '+', "Ej. 2.1 - La salida de la función clasificar_EDS no está bien definido."
assert clasificar_EDS(['EDS2', 'MAGDALENA',  5000], gasolina_prom, gasolina_desv) == '----', "Ej. 2.1 - La salida de la función clasificar_EDS no está bien definido."
print("¡El Ejercicio 2.1 luce bien!")
# Out:
# ¡El Ejercicio 2.1 luce bien!

# %%
# Ejercicio 2.2
assert "clasificaciones" in globals(), "Ej. 2.2 - No definiste una variable llamada clasificaciones"
assert type(clasificaciones)==type([1]), "Ej. 2.2 - La variable clasificaciones no está definida como una lista"
assert  len(clasificaciones) == 4492, "Ej. 2.2 - El número de elementos en clasificaciones es diferente al número de estaciones de servicio en la base de datos, que es 4492"
assert clasificaciones[0] == 'o', "Ej. 2.2 - Hay un problema con los valores listados en clasificaciones."
assert clasificaciones[100] == 'o', "Ej. 2.2 - Hay un problema con los valores listados en clasificaciones."
assert clasificaciones[1000] == 'NoData', "Ej. 2.2 - Hay un problema con los valores listados en clasificaciones."
assert clasificaciones[3000] == '+', "Ej. 2.2 - Hay un problema con los valores listados en clasificaciones."
print("¡El Ejercicio 2.2 luce bien!")
# Out:
# ¡El Ejercicio 2.2 luce bien!

# %%
# Ejercicio 2.3
assert "porc_caras" in globals(), "Ej. 2.3 - No definiste una variable llamada porc_caras"
assert type(porc_caras)==type(1.1), "Ej. 2.3 - La variable porc_caras no está definida como un número flotante"
assert abs(porc_caras-2.671415850400712) < 0.1, "Ej. 2.3 - El valor del porcentaje de estaciones de servicio caras no corresponde al esperado, revisa tu cálculo"
print("¡El Ejercicio 2.3 luce bien!")
# Out:
# ¡El Ejercicio 2.3 luce bien!

# %%
# Ejercicio 2.3
assert "porc_baratas" in globals(), "Ej. 2.4 - No definiste una variable llamada porc_baratas"
assert type(porc_baratas)==type(1.1), "Ej. 2.4 - La variable porc_baratas no está definida como un número flotante"
assert abs(porc_baratas - 0.8459483526268923) < 0.1, "Ej. 2.4 - El valor del porcentaje de estaciones de servicio baratas no corresponde al esperado, revisa tu cálculo"
print("¡El Ejercicio 2.4 luce bien!")
# Out:
# ¡El Ejercicio 2.4 luce bien!
